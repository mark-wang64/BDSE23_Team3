# %%
import requests
from bs4 import BeautifulSoup
import math,time
import random
from fake_useragent import UserAgent
import csv
import pandas as pd
import re

df = pd.read_csv('Edinburgh.csv',encoding='utf-8') # 讀取所有飯店頁面的urL
url_list=pd.unique(df['網址'])


def request_graphql(url,page=0):
    url = url.split("-")
    geo = url[1][1:]
    loc = url[2][1:]
    ua = UserAgent()
    user_agent = ua.random # random user-agent
    request=[
            {"query":"0eb3cf00f96dd65239a88a6e12769ae1",
            "variables":{
                "interaction":{
                    "productInteraction":{
                        "interaction_type":"CLICK",
                        "site":{
                            "site_name":"ta",
                            "site_business_unit":"Hotels",
                            "site_domain":"www.tripadvisor.com.tw"
                            },
                            "pageview":{
                                "pageview_request_uid":"938e8cc8-a9bf-457e-b22a-77ca6786ae5d",
                                "pageview_attributes":{
                                    "location_id":loc,
                                    "geo_id":geo,
                                    "servlet_name":"Hotel_Review"
                                  }
                            },
                            "user":{
                                "user_agent":"Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:96.0) Gecko/20100101 Firefox/96.0",
                                "site_persistent_user_uid":"web107a.61.230.70.72.17EC928A1E7",
                                "unique_user_identifiers":{
                                    "session_id":"352E87D8303944DBB7BEE7D445FE036D"
                                }
                            },
                            "search":{},
                            "item_group":{
                                "item_group_collection_key":"938e8cc8-a9bf-457e-b22a-77ca6786ae5d"
                            },
                            "item":{
                                "product_type":"Hotels",
                                "item_id_type":"ta-location-id",
                                "item_id":loc,
                                "item_attributes":{
                                    "element_type":"next",
                                    "action_name":"REVIEW_NAV",
                                    "page_number":3,
                                    "offset":10,
                                    "limit":5}
                                  }
                            }
                      }
                }
            },
            {"query":"ea9aad8c98a6b21ee6d510fb765a6522",
            "variables":{
                "locationId":loc,
                "offset":page*20,
                "filters":[{"axis":"LANGUAGE","selections":["en"]}],
                "prefs":None,
                "initialPrefs":{},
                "limit":20,
                "filterCacheKey":None,
                "prefsCacheKey":"locationReviewPrefs",
                "needKeywords":"false",
                "keywordVariant":"location_keywords_v2_llr_order_30_zhTW"
                }
            },
            {"query":"e47b7de100177531430992d789c646b6",
            "variables":{
                "pageAdsRequestInput":{
                    "hotelTravelInfo":{
                        "checkInDate":"2022-02-13",
                        "checkOutDate":"2022-02-14",
                        "defaultDates":"true"
                    },
                    "locationId":loc,
                    "pageType":"Hotel_Review",
                    "browserType":"UNKNOWN",
                    "drs":[{"space":"ABC","sliceNum":65},{"space":"AFIL","sliceNum":38},{"space":"ATTPromo","sliceNum":89},{"space":"AUC","sliceNum":89},{"space":"BBML","sliceNum":44},{"space":"BMP","sliceNum":89},{"space":"BRDTTD","sliceNum":76},{"space":"Brand","sliceNum":93},{"space":"CAKE","sliceNum":71},{"space":"CAR","sliceNum":67},{"space":"COM","sliceNum":67},{"space":"CRS","sliceNum":74},{"space":"Community","sliceNum":82},{"space":"Content","sliceNum":0},{"space":"CoreX","sliceNum":92},{"space":"EATPIZZA","sliceNum":50},{"space":"EID","sliceNum":17},{"space":"EXP","sliceNum":8},{"space":"Engage","sliceNum":12},{"space":"FDP","sliceNum":16},{"space":"FDS","sliceNum":12},{"space":"FDU","sliceNum":88},{"space":"FLTMERCH","sliceNum":20},{"space":"FLTREV","sliceNum":47},{"space":"Filters","sliceNum":55},{"space":"Flights","sliceNum":10},{"space":"HRATF","sliceNum":56},{"space":"HSX","sliceNum":30},{"space":"HSXB","sliceNum":9},{"space":"IBEX","sliceNum":15},{"space":"ING","sliceNum":63},{"space":"INT1","sliceNum":93},{"space":"INT2","sliceNum":41},{"space":"ITR","sliceNum":68},{"space":"L10N","sliceNum":40},{"space":"ML","sliceNum":91},{"space":"ML6","sliceNum":92},{"space":"MM","sliceNum":89},{"space":"MOBILEAPP","sliceNum":-1},{"space":"MOF","sliceNum":52},{"space":"MPS","sliceNum":14},{"space":"MTA","sliceNum":57},{"space":"Me2","sliceNum":59},{"space":"Mem","sliceNum":89},{"space":"Mobile","sliceNum":12},{"space":"MobileCore","sliceNum":33},{"space":"Notifications","sliceNum":42},{"space":"Other","sliceNum":25},{"space":"P13N","sliceNum":32},{"space":"PIE","sliceNum":86},{"space":"PLS","sliceNum":86},{"space":"POS","sliceNum":12},{"space":"PRT","sliceNum":79},{"space":"RDS1","sliceNum":38},{"space":"RDS2","sliceNum":68},{"space":"RDS3","sliceNum":74},{"space":"RDS4","sliceNum":27},{"space":"RDS5","sliceNum":76},{"space":"RET","sliceNum":61},{"space":"REV","sliceNum":88},{"space":"REVB","sliceNum":19},{"space":"REVH","sliceNum":58},{"space":"REVM","sliceNum":2},{"space":"REVSD","sliceNum":19},{"space":"REVSP","sliceNum":64},{"space":"REVXS","sliceNum":5},{"space":"RNA","sliceNum":43},{"space":"RSE1","sliceNum":22},{"space":"RSE2","sliceNum":65},{"space":"Rooms","sliceNum":43},{"space":"S3PO","sliceNum":37},{"space":"SD40","sliceNum":58},{"space":"SE2O","sliceNum":68},{"space":"SEM","sliceNum":82},{"space":"SEO","sliceNum":3},{"space":"SORT1","sliceNum":60},{"space":"Sales","sliceNum":66},{"space":"Search","sliceNum":75},{"space":"SiteX","sliceNum":72},{"space":"Surveys","sliceNum":45},{"space":"T4B","sliceNum":92},{"space":"TGT","sliceNum":85},{"space":"TRP","sliceNum":96},{"space":"TTD","sliceNum":21},{"space":"TX","sliceNum":63},{"space":"Timeline","sliceNum":29},{"space":"VP","sliceNum":93},{"space":"VR","sliceNum":40},{"space":"YM","sliceNum":44},{"space":"YMB","sliceNum":33}],"globalContextUrlParameters":[{"key":"detailId","value":"12971308"},{"key":"geoId","value":"186338"},{"key":"offset","value":"r10"}],"userAgentCategory":"DESKTOP"}}}   
      ]

    response=requests.post(url_graph,json=request,headers={
          "origin":"https://www.tripadvisor.com",
          "pragma":"no-cache",
          "referer":"https://www.tripadvisor.com.tw/Hotel_Review-g186338-d12971308-Reviews-or10-New_Road_Hotel-London_England.html#REVIEWS",
          "user-agent":user_agent,
          "x-requested-by":"TNI1625!AMAZ8ONySXaYlvWaXDO8Mxrekk1yefdKrdHBz7rLaI7/zSxYDzhGczHC89lznR+fzOxDGQoiNrBfWlOB7GLig8oFxzxYz01zZ30WSFcgdCFT9G5I44KghQDziFXbZm1misNXlLdmCcoDsKn4muzndpmpP51obn1eoavdFY0P0p5q",
8942F3E11BE54~EKgoMO8WAMEX7AtW+bt7dnYfHe2UsoVXli605C5QgfrtQx9TeuXATEfi/a206+F0tVT+Lq4y/VAn2ULNDFsIDzpp9cTY7rnqG38yqmt4qQ3R9JF2/eskgr+QfcCGzJAywDk/AqVTFzrpVcjD3gsovAtqsNdTr7eGa9rCg2uWVw8=; roybatty=TNI1625!ACr9VtNuLj5totXJaU%2B8xFHSrXdGjHyvoYY%2B0JO5Io6kgrBDeSpjk2UnWkl%2BKOZIdKzxtvhF3NwbB8WC514UpwxVIwTh8ecPaMaQUht8SdinTxgD%2FszYvncqWNS84Hl4VkJRHBRLR9hj94juIVjzh1wsYoiNLOMTkkveKRQ%2FghCP%2C1; _em_c3=0; _em_vi=b4ece5ad-b4f3-4ff7-90c5-cb063dea4250-17eca5891bc-93eddcff; _em_lt=1644072309180; _em_ft=1644072309180; _em_pc=1; SRT=%1%enc%3AXkFOqv155sSTI4MdCA6WE8LG9e99EVUKVGQwQiQszhHCAvSUdoPYC5PVm46UqhC8yx9HjuV9fk0%3D; _lr_sampling_rate=100; _lr_retry_request=true"


    })
    return response.json()



for url in url_list:
    data=[]
    url_graph = "https://www.tripadvisor.com/data/graphql/ids"
    res = request_graphql(url)[1]["data"]["locations"][0] # 抓出原始碼
    if res["reviewListPage"]["totalCount"] is not None:
        total_reviews = res["reviewListPage"]["totalCount"]
    else:
        continue
    if res['reviewSummary']["rating"] is not None:
        total_rating = res['reviewSummary']["rating"]
    else:
        total_rating=[]
        continue
    pages = math.ceil(total_reviews/20) # 計算出總要抓取的次數
    print(pages)
    if pages=0:
      continue
    hotel_name = re.sub(r'[^\w\s]','',res["name"])
    print(hotel_name)
    print(total_rating)
    # 開始每次二十條評論的抓取迴圈
    for i in range(pages+1):
        time.sleep(random.randint(3,6))
        res = request_graphql(url,page=i)[1]["data"]["locations"][0]
        reviews = res["reviewListPage"]["reviews"] if res["reviewListPage"]["reviews"] is not None else []
        
        # 二十條評論抓取後儲存
        for review in reviews:
            review_title=review["title"] if review["title"] is not None else []
            review_text=review["text"] if review["text"] is not None else []
            review_data={
                "Hotel Name": hotel_name,
                "total rating": total_rating,
                "Review Date": review["createdDate"] if review["createdDate"] is not None else [],
                "Stay Date": review["tripInfo"]["stayDate"] if review["tripInfo"] is not None else [],
                "Trip Type": review["tripInfo"]["tripType"] if review["tripInfo"] is not None else [],
                "Language": review["originalLanguage"] if review["originalLanguage"] is not None else [],
                "Room Tip": review["roomTip"] if "roomTip" in review else None,
                "Review Title":review_title,
                "Review Rating": review["rating"],
                "Review Text": review_text,
                "User Name": review["userProfile"]["displayName"] if review["userProfile"] else None,
                "Hometown": review["userProfile"]["hometown"]["location"]["additionalNames"]["long"] if review["userProfile"] is not None and review["userProfile"]["hometown"]["location"] is not None else None
            }
            if review["additionalRatings"] is not None:
                for rating in review["additionalRatings"]:
                    review_data[f'[{rating["ratingLabel"]} Stars'] = rating['rating']                
            data.append(review_data) # 單次循環儲存
    # 飯店評論總存檔
    df = pd.DataFrame(data) 
    df.to_csv(hotel_name+'.csv', index=False, encoding='utf-8-sig', sep=',') # 路徑要自己設定
    print(hotel_name)
# Out:
# 14
# Market Street Hotel
# 4.5
# Market Street Hotel
# 28
# Fingal
# 5.0
